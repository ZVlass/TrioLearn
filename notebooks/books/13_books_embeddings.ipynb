# %% [markdown]
# Embedding Book Metadata with all-MiniLM-L6-v2

# %%
import os
import pandas as pd
from sentence_transformers import SentenceTransformer
import numpy as np

# %%
os.chdir("..")  # Go up to project root

# %%
df_books = pd.read_csv("C:/Users/jvlas/source/repos/TrioLearn/data/interim/books_metadata.csv")

# %%
# Fill missing fields (avoid errors during string joining)
df_books.fillna("", inplace=True)
# Out:
# C:\Users\jvlas\AppData\Local\Temp\ipykernel_73844\1538531904.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_books.fillna("", inplace=True)

# %%
# Combine text fields into one string for embedding
df_books["text_for_embedding"] = (
    df_books["title"] + " " +
    df_books["description"] + " " +
    df_books["categories"]
)

# %%
# Load the pre-trained Sentence-BERT model
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\transformers\utils\import_utils.py:2045, in __getattr__(self, name)
#    2014 MISTRAL_COMMON_IMPORT_ERROR = """
#    2015 {0} requires the mistral-common library but it was not found in your environment. You can install it with pip: `pip install mistral-common`. Please note that you may need to restart your runtime after installation.
#    2016 """
#    2019 BACKENDS_MAPPING = OrderedDict(
#    2020     [
#    2021         ("av", (is_av_available, AV_IMPORT_ERROR)),
#    2022         ("bs4", (is_bs4_available, BS4_IMPORT_ERROR)),
#    2023         ("cv2", (is_cv2_available, CV2_IMPORT_ERROR)),
#    2024         ("datasets", (is_datasets_available, DATASETS_IMPORT_ERROR)),
#    2025         ("decord", (is_decord_available, DECORD_IMPORT_ERROR)),
#    2026         ("detectron2", (is_detectron2_available, DETECTRON2_IMPORT_ERROR)),
#    2027         ("essentia", (is_essentia_available, ESSENTIA_IMPORT_ERROR)),
#    2028         ("faiss", (is_faiss_available, FAISS_IMPORT_ERROR)),
#    2029         ("flax", (is_flax_available, FLAX_IMPORT_ERROR)),
#    2030         ("ftfy", (is_ftfy_available, FTFY_IMPORT_ERROR)),
#    2031         ("g2p_en", (is_g2p_en_available, G2P_EN_IMPORT_ERROR)),
#    2032         ("pandas", (is_pandas_available, PANDAS_IMPORT_ERROR)),
#    2033         ("phonemizer", (is_phonemizer_available, PHONEMIZER_IMPORT_ERROR)),
#    2034         ("uroman", (is_uroman_available, UROMAN_IMPORT_ERROR)),
#    2035         ("pretty_midi", (is_pretty_midi_available, PRETTY_MIDI_IMPORT_ERROR)),
#    2036         ("levenshtein", (is_levenshtein_available, LEVENSHTEIN_IMPORT_ERROR)),
#    2037         ("librosa", (is_librosa_available, LIBROSA_IMPORT_ERROR)),
#    2038         ("protobuf", (is_protobuf_available, PROTOBUF_IMPORT_ERROR)),
#    2039         ("pyctcdecode", (is_pyctcdecode_available, PYCTCDECODE_IMPORT_ERROR)),
#    2040         ("pytesseract", (is_pytesseract_available, PYTESSERACT_IMPORT_ERROR)),
#    2041         ("sacremoses", (is_sacremoses_available, SACREMOSES_IMPORT_ERROR)),
#    2042         ("pytorch_quantization", (is_pytorch_quantization_available, PYTORCH_QUANTIZATION_IMPORT_ERROR)),
#    2043         ("sentencepiece", (is_sentencepiece_available, SENTENCEPIECE_IMPORT_ERROR)),
#    2044         ("sklearn", (is_sklearn_available, SKLEARN_IMPORT_ERROR)),
# -> 2045         ("speech", (is_speech_available, SPEECH_IMPORT_ERROR)),
#    2046         ("tensorflow_probability", (is_tensorflow_probability_available, TENSORFLOW_PROBABILITY_IMPORT_ERROR)),
#    2047         ("tf", (is_tf_available, TENSORFLOW_IMPORT_ERROR)),
#    2048         ("tensorflow_text", (is_tensorflow_text_available, TENSORFLOW_TEXT_IMPORT_ERROR)),
#    2049         ("timm", (is_timm_available, TIMM_IMPORT_ERROR)),
#    2050         ("torchaudio", (is_torchaudio_available, TORCHAUDIO_IMPORT_ERROR)),
#    2051         ("natten", (is_natten_available, NATTEN_IMPORT_ERROR)),
#    2052         ("nltk", (is_nltk_available, NLTK_IMPORT_ERROR)),
#    2053         ("tokenizers", (is_tokenizers_available, TOKENIZERS_IMPORT_ERROR)),
#    2054         ("torch", (is_torch_available, PYTORCH_IMPORT_ERROR)),
#    2055         ("torchvision", (is_torchvision_available, TORCHVISION_IMPORT_ERROR)),
#    2056         ("torchcodec", (is_torchcodec_available, TORCHCODEC_IMPORT_ERROR)),
#    2057         ("vision", (is_vision_available, VISION_IMPORT_ERROR)),
#    2058         ("scipy", (is_scipy_available, SCIPY_IMPORT_ERROR)),
#    2059         ("accelerate", (is_accelerate_available, ACCELERATE_IMPORT_ERROR)),
#    2060         ("oneccl_bind_pt", (is_ccl_available, CCL_IMPORT_ERROR)),
#    2061         ("cython", (is_cython_available, CYTHON_IMPORT_ERROR)),
#    2062         ("jieba", (is_jieba_available, JIEBA_IMPORT_ERROR)),
#    2063         ("peft", (is_peft_available, PEFT_IMPORT_ERROR)),
#    2064         ("jinja", (is_jinja_available, JINJA_IMPORT_ERROR)),
#    2065         ("yt_dlp", (is_yt_dlp_available, YT_DLP_IMPORT_ERROR)),
#    2066         ("rich", (is_rich_available, RICH_IMPORT_ERROR)),
#    2067         ("keras_nlp", (is_keras_nlp_available, KERAS_NLP_IMPORT_ERROR)),
#    2068         ("pydantic", (is_pydantic_available, PYDANTIC_IMPORT_ERROR)),
#    2069         ("fastapi", (is_fastapi_available, FASTAPI_IMPORT_ERROR)),
#    2070         ("uvicorn", (is_uvicorn_available, UVICORN_IMPORT_ERROR)),
#    2071         ("openai", (is_openai_available, OPENAI_IMPORT_ERROR)),
#    2072         ("mistral-common", (is_mistral_common_available, MISTRAL_COMMON_IMPORT_ERROR)),
#    2073     ]
#    2074 )
#    2077 def requires_backends(obj, backends):
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\transformers\utils\import_utils.py:2075, in _get_module(self, module_name)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\transformers\utils\import_utils.py:2073, in _get_module(self, module_name)
#    2014 MISTRAL_COMMON_IMPORT_ERROR = """
#    2015 {0} requires the mistral-common library but it was not found in your environment. You can install it with pip: `pip install mistral-common`. Please note that you may need to restart your runtime after installation.
#    2016 """
#    2019 BACKENDS_MAPPING = OrderedDict(
#    2020     [
#    2021         ("av", (is_av_available, AV_IMPORT_ERROR)),
#    2022         ("bs4", (is_bs4_available, BS4_IMPORT_ERROR)),
#    2023         ("cv2", (is_cv2_available, CV2_IMPORT_ERROR)),
#    2024         ("datasets", (is_datasets_available, DATASETS_IMPORT_ERROR)),
#    2025         ("decord", (is_decord_available, DECORD_IMPORT_ERROR)),
#    2026         ("detectron2", (is_detectron2_available, DETECTRON2_IMPORT_ERROR)),
#    2027         ("essentia", (is_essentia_available, ESSENTIA_IMPORT_ERROR)),
#    2028         ("faiss", (is_faiss_available, FAISS_IMPORT_ERROR)),
#    2029         ("flax", (is_flax_available, FLAX_IMPORT_ERROR)),
#    2030         ("ftfy", (is_ftfy_available, FTFY_IMPORT_ERROR)),
#    2031         ("g2p_en", (is_g2p_en_available, G2P_EN_IMPORT_ERROR)),
#    2032         ("pandas", (is_pandas_available, PANDAS_IMPORT_ERROR)),
#    2033         ("phonemizer", (is_phonemizer_available, PHONEMIZER_IMPORT_ERROR)),
#    2034         ("uroman", (is_uroman_available, UROMAN_IMPORT_ERROR)),
#    2035         ("pretty_midi", (is_pretty_midi_available, PRETTY_MIDI_IMPORT_ERROR)),
#    2036         ("levenshtein", (is_levenshtein_available, LEVENSHTEIN_IMPORT_ERROR)),
#    2037         ("librosa", (is_librosa_available, LIBROSA_IMPORT_ERROR)),
#    2038         ("protobuf", (is_protobuf_available, PROTOBUF_IMPORT_ERROR)),
#    2039         ("pyctcdecode", (is_pyctcdecode_available, PYCTCDECODE_IMPORT_ERROR)),
#    2040         ("pytesseract", (is_pytesseract_available, PYTESSERACT_IMPORT_ERROR)),
#    2041         ("sacremoses", (is_sacremoses_available, SACREMOSES_IMPORT_ERROR)),
#    2042         ("pytorch_quantization", (is_pytorch_quantization_available, PYTORCH_QUANTIZATION_IMPORT_ERROR)),
#    2043         ("sentencepiece", (is_sentencepiece_available, SENTENCEPIECE_IMPORT_ERROR)),
#    2044         ("sklearn", (is_sklearn_available, SKLEARN_IMPORT_ERROR)),
#    2045         ("speech", (is_speech_available, SPEECH_IMPORT_ERROR)),
#    2046         ("tensorflow_probability", (is_tensorflow_probability_available, TENSORFLOW_PROBABILITY_IMPORT_ERROR)),
#    2047         ("tf", (is_tf_available, TENSORFLOW_IMPORT_ERROR)),
#    2048         ("tensorflow_text", (is_tensorflow_text_available, TENSORFLOW_TEXT_IMPORT_ERROR)),
#    2049         ("timm", (is_timm_available, TIMM_IMPORT_ERROR)),
#    2050         ("torchaudio", (is_torchaudio_available, TORCHAUDIO_IMPORT_ERROR)),
#    2051         ("natten", (is_natten_available, NATTEN_IMPORT_ERROR)),
#    2052         ("nltk", (is_nltk_available, NLTK_IMPORT_ERROR)),
#    2053         ("tokenizers", (is_tokenizers_available, TOKENIZERS_IMPORT_ERROR)),
#    2054         ("torch", (is_torch_available, PYTORCH_IMPORT_ERROR)),
#    2055         ("torchvision", (is_torchvision_available, TORCHVISION_IMPORT_ERROR)),
#    2056         ("torchcodec", (is_torchcodec_available, TORCHCODEC_IMPORT_ERROR)),
#    2057         ("vision", (is_vision_available, VISION_IMPORT_ERROR)),
#    2058         ("scipy", (is_scipy_available, SCIPY_IMPORT_ERROR)),
#    2059         ("accelerate", (is_accelerate_available, ACCELERATE_IMPORT_ERROR)),
#    2060         ("oneccl_bind_pt", (is_ccl_available, CCL_IMPORT_ERROR)),
#    2061         ("cython", (is_cython_available, CYTHON_IMPORT_ERROR)),
#    2062         ("jieba", (is_jieba_available, JIEBA_IMPORT_ERROR)),
#    2063         ("peft", (is_peft_available, PEFT_IMPORT_ERROR)),
#    2064         ("jinja", (is_jinja_available, JINJA_IMPORT_ERROR)),
#    2065         ("yt_dlp", (is_yt_dlp_available, YT_DLP_IMPORT_ERROR)),
#    2066         ("rich", (is_rich_available, RICH_IMPORT_ERROR)),
#    2067         ("keras_nlp", (is_keras_nlp_available, KERAS_NLP_IMPORT_ERROR)),
#    2068         ("pydantic", (is_pydantic_available, PYDANTIC_IMPORT_ERROR)),
#    2069         ("fastapi", (is_fastapi_available, FASTAPI_IMPORT_ERROR)),
#    2070         ("uvicorn", (is_uvicorn_available, UVICORN_IMPORT_ERROR)),
#    2071         ("openai", (is_openai_available, OPENAI_IMPORT_ERROR)),
#    2072         ("mistral-common", (is_mistral_common_available, MISTRAL_COMMON_IMPORT_ERROR)),
# -> 2073     ]
#    2074 )
#    2077 def requires_backends(obj, backends):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.models.llama4.configuration_llama4'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Load the pre-trained Sentence-BERT model
# ----> 2 model = SentenceTransformer("all-MiniLM-L6-v2")
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\sentence_transformers\SentenceTransformer.py:309, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     300         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
#     302 if is_sentence_transformer_model(
#     303     model_name_or_path,
#     304     token,
#    (...)
#     307     local_files_only=local_files_only,
#     308 ):
# --> 309     modules, self.module_kwargs = self._load_sbert_model(
#     310         model_name_or_path,
#     311         token=token,
#     312         cache_folder=cache_folder,
#     313         revision=revision,
#     314         trust_remote_code=trust_remote_code,
#     315         local_files_only=local_files_only,
#     316         model_kwargs=model_kwargs,
#     317         tokenizer_kwargs=tokenizer_kwargs,
#     318         config_kwargs=config_kwargs,
#     319     )
#     320 else:
#     321     modules = self._load_auto_model(
#     322         model_name_or_path,
#     323         token=token,
#    (...)
#     330         config_kwargs=config_kwargs,
#     331     )
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\sentence_transformers\SentenceTransformer.py:1808, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    1805 # Try to initialize the module with a lot of kwargs, but only if the module supports them
#    1806 # Otherwise we fall back to the load method
#    1807 try:
# -> 1808     module = module_class(model_name_or_path, cache_dir=cache_folder, backend=self.backend, **kwargs)
#    1809 except TypeError:
#    1810     module = module_class.load(model_name_or_path)
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\sentence_transformers\models\Transformer.py:81, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#      78     config_args = {}
#      80 config, is_peft_model = self._load_config(model_name_or_path, cache_dir, backend, config_args)
# ---> 81 self._load_model(model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#      83 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#      84     tokenizer_args["model_max_length"] = max_seq_length
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\sentence_transformers\models\Transformer.py:181, in Transformer._load_model(self, model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#     179     self._load_mt5_model(model_name_or_path, config, cache_dir, **model_args)
#     180 else:
# --> 181     self.auto_model = AutoModel.from_pretrained(
#     182         model_name_or_path, config=config, cache_dir=cache_dir, **model_args
#     183     )
#     185 if is_peft_model:
#     186     self._load_peft_model(model_name_or_path, config, cache_dir, **model_args, **adapter_only_kwargs)
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\transformers\models\auto\auto_factory.py:547, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     544         kwargs["quantization_config"] = kwargs_orig["quantization_config"]
#     546 has_remote_code = hasattr(config, "auto_map") and cls.__name__ in config.auto_map
# --> 547 has_local_code = type(config) in cls._model_mapping.keys()
#     548 trust_remote_code = resolve_trust_remote_code(
#     549     trust_remote_code, pretrained_model_name_or_path, has_local_code, has_remote_code
#     550 )
#     551 kwargs["trust_remote_code"] = trust_remote_code
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\transformers\models\auto\auto_factory.py:791, in _LazyAutoMapping.keys(self)
#     790 def keys(self):
# --> 791     mapping_keys = [
#     792         self._load_attr_from_module(key, name)
#     793         for key, name in self._config_mapping.items()
#     794         if key in self._model_mapping.keys()
#     795     ]
#     796     return mapping_keys + list(self._extra_content.keys())
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\transformers\models\auto\auto_factory.py:792, in <listcomp>(.0)
#     790 def keys(self):
#     791     mapping_keys = [
# --> 792         self._load_attr_from_module(key, name)
#     793         for key, name in self._config_mapping.items()
#     794         if key in self._model_mapping.keys()
#     795     ]
#     796     return mapping_keys + list(self._extra_content.keys())
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\transformers\models\auto\auto_factory.py:788, in _load_attr_from_module(self, model_type, attr)
#     786 self._config_mapping = config_mapping
#     787 self._reverse_config_mapping = {v: k for k, v in config_mapping.items()}
# --> 788 self._model_mapping = model_mapping
#     789 self._model_mapping._model_mapping = self
#     790 self._extra_content = {}
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\transformers\models\auto\auto_factory.py:700, in getattribute_from_module(module, attr)
#     698     from_pretrained_docstring = FROM_PRETRAINED_FLAX_DOCSTRING
#     699 else:
# --> 700     from_pretrained_docstring = FROM_PRETRAINED_TORCH_DOCSTRING
#     701 from_pretrained = copy_func(_BaseAutoModelClass.from_pretrained)
#     702 from_pretrained_docstring = insert_head_doc(from_pretrained_docstring, head_doc=head_doc)
#
# File c:\Users\jvlas\source\repos\TrioLearn\.venv\lib\site-packages\transformers\utils\import_utils.py:2048, in __getattr__(self, name)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ModuleNotFoundError: Could not import module 'Llama4Config'. Are this object's requirements defined correctly?

# %%
#  Compute embeddings (batch process for performance)
embeddings = model.encode(df_books["text_for_embedding"].tolist(), show_progress_bar=True)

# %%
# Store as separate columns
embedding_df = pd.DataFrame(embeddings, columns=[f"emb_{i}" for i in range(embeddings.shape[1])])

# %%
# Concatenate with original metadata
df_books_embedded = pd.concat([df_books, embedding_df], axis=1)

# %%
processed_dir = os.path.join("data", "processed")
os.makedirs(processed_dir, exist_ok=True)


save_path = os.path.join(processed_dir, "books_with_embeddings.csv")
df_books_embedded.to_csv(save_path, index=False)

print(f"Saved {len(df_books_embedded)} books with embeddings to:", save_path)
